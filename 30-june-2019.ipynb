# %%
### python librery for data analysis
### pandas - Data Analysis
- series Object- one - dimensional data

# %%
s='All-convoYs-9-be:Alert1.'
al=[]
for i in s:
    if i.isalpha():
        
        b=chr(ord(i)+4)
        al.append(b)
        c=''.join(al)
print(c)
# Out:
# Eppgsrzs]wfiEpivx

# %%
#Function to read csv data into a DataFrame and 
#return the data freme object

filepath='DataFiles/Income.csv'
import pandas as pd
def readCSVdata(filepath):
    return pd.read_csv(filepath)

readCSVdata(filepath)
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
incomedf=readCSVdata(filepath)

#function to print all column names in a sinle line
#GEOID state 2005 2006 2007 2008 2009 2010 2011 2012 2013
def printdataframecolumn(df):
    columns = df.columns
    for column in columns:
        print(column,end=' ')
    return
printdataframecolumn(incomedf)
# Out:
# GEOID State 2005 2006 2007 2008 2009 2010 2011 2012 2013

# %%
columns = incomedf.columns
' '.join(columns)
# Out:
# 'GEOID State 2005 2006 2007 2008 2009 2010 2011 2012 2013'

# %%
#function to access a row based on unique column value
def accessdataframerow(df,key):
    for row in df.values:
        if key in row:
            for item in row:
                print(item,end=" ")
            print('\n')
    return
accessdataframerow(incomedf,'Alaska')
# Out:
# 04000US02 Alaska 55891 56418 62993 63989 61604 57848 57431 63648 61137

# %%
incomedf.values[2][4]=62994
incomedf
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
#Accessing a unique value based on row,column information
#Income of a state in a given year
def getrowindex(df,rowkey):
    for i in range(len(df.values)):
        if df.values[i][0]==rowkey or df.values[i][1]==rowkey:
            rowindex=i
    return rowindex
def getcolumnindex(df,columnkey):
    for i in range(len(df.columns)):
        if df.columns[i]==columnkey:
            columnindex=i
    return columnindex
    
def valueFromRowColumn(df,rowkey,columnkey):
    rowindex=getrowindex(df,rowkey)
    columnindex=getcolumnindex(df,columnkey)
    return df.values[rowindex][columnindex]
valueFromRowColumn(incomedf,'Arizona','2007')
# Out:
# 47215

# %%
#Function to update data based on rowkey and columnkey
def updatedatafromrowcolumn(df,rowkey,columnkey,newdata):
    rowindex=getrowindex(df,rowkey)
    columnindex=getcolumnindex(df,columnkey)
    row=df.values[rowindex]
    row[columnindex]=newdata
    df.loc[rowindex]=row
    return
updatedatafromrowcolumn(incomedf,'Arizona','2007',62993)
incomedf
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
accessdataframerow(incomedf,62993)
# Out:
# 04000US02 Alaska 55891 56418 62993 63989 61604 57848 57431 63648 61137
#
# 04000US04 Arizona 45245 46657 62993 46914 45739 46896 48621 47044 50602

# %%
#function to write data frame to csv

incomedf.to_csv(filepath,index=False)

# %%
#function to add a new row of data to DataFrame
def addrowtodataframe(df,rowdata):
    lastrowindex=len(df.values)-1
    df.loc[lastrowindex+1]=rowdata
    return
rowdata=[234,567,890,123,345,567,678,987,134,953,456]
addrowtodataframe(incomedf,rowdata)

# %%
incomedf
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
# 5        234         567    890    123    345    567    678    987    134
# 6        234         567    890    123    345    567    678    987    134
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528
# 5    953    456
# 6    953    456

# %%
def delrowfromdata(df,rowkey):
    rowindex=getrowindex(df,rowkey)
    df.drop([rowindex],axis=0)
    return
#delrowfromdata(incomedf,1)
incomedf=incomedf.drop([6])

# %%
incomedf
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528
