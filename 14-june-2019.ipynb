# %% [markdown]
# ### day objectives
# - python data structures
#     - Lists
#     - Tuples
#     - Dictionaries
# - Basic Problem set on Data Structures
# - Advanced Problem Set
# - Packages and Modules in Python

# %% [markdown]
# ## python data structures

# %% [markdown]
# ### Lists

# %%
li=[123,978,654]

li #access the entire list

li[1]#access an element with index in a list

li[1:]#access all elements from second element to alst elemrnt

li=li[::-1]#reversing list elements in list and reasigning data

li

li=li[::-1]

li[::2]#accessing even index elements

li[1::2]

#list can be accessed,maniplated in two different ways
 #direct referencing - [index]
 #indirect referencing - through functions


li.append(345)#addind an element to end of the list

li.insert(1,234)# Adding an element at a particulat

li.sort()#sort elements in ascending order

li.pop()#remove the last element in a list

li.pop(1)#remove an element at a particular index

li2 = [234,456,789]

li.extend(li2)#merge list 2 into list 1

sum(li)#sum of elements a list
max(li)#maximum element in the list
len(li)#number of elements in a list

sum(li)/len(li)#Average of elements in a list
#average of all alternate elements
li
#li[::-5]
#sum(li[::2])/len(li[::2])
#min(li)
#li[len(li)-2]
try:
    li.index(456)
except:
    -1

# %%
#function to identify the second largest element in the list
def secondlargest(li):
    li=sorted(li)
    return li[len(li)-2]
secondlargest(li)
# Out:
# 654

# %%
#function that returns the n th largest
def Nthlargest(li,n):
    li.sort()
    return li[-n]
Nthlargest(li,2)
# Out:
# 654

# %%
#function to search for data in a list
#search for the key in the list and return the index of list
#def linearsearch(li,key):
#   for i in li:
#        if i==key: 
#            return i
#    return -1

def linearSearch1(li,key):
    if key in li:
        return li.index(key)
    return -1
linearsearch(li,456)
# Out:
# 456

# %%
# function to count the occurences of a charecter in a string
#"pythonprogramming",m->2
#def countcharoccurence(s,c):
#    count = 0
#    for ch in s:
#        count +=1
#    return count

def countcharoccurence(s,c):
    return s.count(c)
countcharoccurence("python programming",'g')
#function to find the number of occurances of a substring
# "abcabcddcba","ab" ->2
def countcharoccurence(s,c):
    return s.count(c)
countcharoccurence("abcabcddcba","ab")
# Out:
# 2

# %%
s="1 2 3 4 5 6"
li = s.split()
numberlist = []
for i in li:
    numberlist.append(int(i))
numberlist
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
n = int(input())
s = input()
li=[]
for i in s.split():
    li.append(abs(int(i))
def closestzero(li):
    nl = []
    for i in li:
        if i < 0:
              nl.append(i)
              
    pl = []
    for i in li:
        if i >= 0:
              pl.append(i)
    nc = max(nl)
    pc = min(pl)
    if 
    if abs(nc) == pc:
        return pc
    elif abs(nc) < pc:
        return abs(nc)
    else:
# Out:
#   File "<ipython-input-6-4b7261171aeb>", line 7
#     min(li)
#       ^
# SyntaxError: invalid syntax

# %%
n=int(input())
s = input()
s = s.split()
li=[]
ni=[]
for i in s:
    ni.append(i)
    li.append(abs(int(i)))
print(ni)
print(li)
mini=li.index(min(li))
print(mini)
ot=ni[mini]
print(ot)
#print(ot)
# Out:
# 4
# 4 2 3 1
# ['4', '2', '3', '1']
# [4, 2, 3, 1]
# 3
# 1

# %%
def isprime(n):
    count=0
    i=0
    while i<=n:
        i=i+1
        if(n%1==0):
            count=count+1
    if(count==2):
        print(i,end=" ")
isprime(5)

# %%
def isprime(u):
    for num in range(2,u+1):
        if num > 1:
            for i in range(2,num):
                if (num % i) == 0:
                    print(i)
    else:
        print(-1)
    
    

isprime(122)
# Out:
# 2
# 2
# 3
# 2
# 4
# 3
# 2
# 5
# 2
# 3
# 4
# 6
# 2
# 7
# 3
# 5
# 2
# 4
# 8
# 2
# 3
# 6
# 9
# 2
# 4
# 5
# 10
# 3
# 7
# 2
# 11
# 2
# 3
# 4
# 6
# 8
# 12
# 5
# 2
# 13
# 3
# 9
# 2
# 4
# 7
# 14
# 2
# 3
# 5
# 6
# 10
# 15
# 2
# 4
# 8
# 16
# 3
# 11
# 2
# 17
# 5
# 7
# 2
# 3
# 4
# 6
# 9
# 12
# 18
# 2
# 19
# 3
# 13
# 2
# 4
# 5
# 8
# 10
# 20
# 2
# 3
# 6
# 7
# 14
# 21
# 2
# 4
# 11
# 22
# 3
# 5
# 9
# 15
# 2
# 23
# 2
# 3
# 4
# 6
# 8
# 12
# 16
# 24
# 7
# 2
# 5
# 10
# 25
# 3
# 17
# 2
# 4
# 13
# 26
# 2
# 3
# 6
# 9
# 18
# 27
# 5
# 11
# 2
# 4
# 7
# 8
# 14
# 28
# 3
# 19
# 2
# 29
# 2
# 3
# 4
# 5
# 6
# 10
# 12
# 15
# 20
# 30
# 2
# 31
# 3
# 7
# 9
# 21
# 2
# 4
# 8
# 16
# 32
# 5
# 13
# 2
# 3
# 6
# 11
# 22
# 33
# 2
# 4
# 17
# 34
# 3
# 23
# 2
# 5
# 7
# 10
# 14
# 35
# 2
# 3
# 4
# 6
# 8
# 9
# 12
# 18
# 24
# 36
# 2
# 37
# 3
# 5
# 15
# 25
# 2
# 4
# 19
# 38
# 7
# 11
# 2
# 3
# 6
# 13
# 26
# 39
# 2
# 4
# 5
# 8
# 10
# 16
# 20
# 40
# 3
# 9
# 27
# 2
# 41
# 2
# 3
# 4
# 6
# 7
# 12
# 14
# 21
# 28
# 42
# 5
# 17
# 2
# 43
# 3
# ...

# %%
def isprime(u):
    for num in range(1,u+1):
        if num % 2 != 0 and num % 1==0:
            print (num)
isprime(10)
# Out:
# 1
# 3
# 5
# 7
# 9
